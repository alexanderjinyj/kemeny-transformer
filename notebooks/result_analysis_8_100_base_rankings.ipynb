# %%
import numpy as np
from time import time
from numba import njit

# %%
test_dataset_random_kemeny_optimal_ranking_gurobi_result=np.load('test_dataset/gurobi_result/test_dataset_random_kemeny_optimal_ranking_gurobi.npy', allow_pickle=True)
test_dataset_random_kemeny_optimal_ranking_distance_gurobi_result=np.load('test_dataset/gurobi_result/test_dataset_random_kemeny_optimal_ranking_distance_gurobi.npy', allow_pickle=True)

# %%
test_dataset_random_kemeny_optimal_ranking_gurobi_result
# Out:
# array({'kemeny_rankings': array([[ 4., 25., 79., ..., 24., 70., 23.],
#        [94., 99., 27., ..., 63., 16., 57.],
#        [30., 36., 81., ..., 31., 35., 50.],
#        ...,
#        [60., 59., 89., ..., 95., 72., 70.],
#        [23., 12., 52., ..., 38., 34., 78.],
#        [60., 51., 92., ..., 62., 65., 47.]], dtype=float32), 'kemeny_rankings_running_time': array([ 11.60116172,   4.67434716, 236.07687712, ...,   6.27516031,
#        141.63073802,  18.03790331]), 'idx_batch': 1999}, dtype=object)

# %%
test_dataset_random_kemeny_optimal_ranking_distance_gurobi_result
# Out:
# array([1867.75 , 1762.   , 1838.   , ..., 1874.875, 1869.75 , 1916.25 ])

# %%
test_dataset_base_rankings_random=np.load('test_dataset/test_dataset_random.npy')

# %%
test_dataset_base_rankings_random[1999]
# Out:
# array([[70., 29., 97.,  4., 14., 30.,  0., 42., 90., 25., 54., 48., 23.,
#         26., 63.,  9., 31., 76., 91., 43., 36., 92., 77., 60.,  8., 55.,
#         99.,  5., 88., 32., 41., 96., 56., 86., 46., 72., 51.,  1., 81.,
#         79., 16., 94., 74., 83., 37., 71., 44., 66., 87.,  2., 59., 75.,
#         45., 13., 12., 89., 47., 27., 10., 62., 69., 68., 20., 57., 53.,
#         67., 24., 21., 49., 11., 93., 17., 95., 85., 28., 58., 82., 98.,
#         65., 34., 18., 15.,  7., 61., 35., 38., 52., 73., 50., 22.,  6.,
#         78., 40., 33., 39., 84.,  3., 64., 80., 19.],
#        [57., 53., 34., 59., 72., 50.,  9., 46., 74., 14., 85., 80., 76.,
#         55., 11., 81., 32., 30., 12., 10., 69., 90.,  5., 27.,  8., 60.,
#         35., 87., 91.,  7., 24., 89., 22., 65., 28., 77., 56., 64., 83.,
#         16., 48., 39., 73., 42., 21., 19., 95., 33., 43., 93., 68., 63.,
#         97., 71., 70., 86., 41., 29., 38., 26., 88., 40., 15., 49., 47.,
# ...

# %%
test_dataset_random_kemeny_optimal_ranking_transformer_result=np.load('test_dataset/transformer_test_result/test_dataset_random_transformer.npy', allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 test_dataset_random_kemeny_optimal_ranking_transformer_result=np.load('test_dataset/transformer_test_result/test_dataset_random_transformer.npy', allow_pickle=True)
#
# File ~/anaconda3/envs/kemeny_transformer/lib/python3.9/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_dataset/transformer_test_result/test_dataset_random_transformer.npy'
