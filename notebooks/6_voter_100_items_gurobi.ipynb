# %%
import numpy as np

# %%
random_optimal_ranking_distance_gurobi = np.load("validate_dataset/6_voters_100_items/validate_dataset_random_kemeny_optimal_ranking_distance_gurobi.npy")

# %%
random_optimal_ranking_distance_gurobi
# Out:
# array([1787.83333333, 1689.5       , 1747.66666667, 1680.5       ,
#        1777.83333333, 1772.5       , 1679.        , 1779.83333333,
#        1719.16666667, 1768.16666667, 1811.66666667, 1703.66666667,
#        1778.        , 1756.        , 1706.5       , 1802.        ,
#        1762.5       , 1667.83333333, 1685.66666667, 1751.5       ,
#        1729.        , 1759.66666667, 1750.5       , 1852.33333333,
#        1733.33333333, 1729.33333333, 1746.        , 1710.5       ,
#        1824.33333333, 1673.16666667, 1693.33333333, 1794.        ,
#        1710.        , 1685.83333333, 1700.16666667, 1798.        ,
#        1765.5       , 1785.33333333, 1769.        , 1807.16666667,
#        1770.16666667, 1689.        , 1702.16666667, 1739.83333333,
#        1842.16666667, 1740.16666667, 1816.83333333, 1640.66666667,
#        1846.33333333, 1760.83333333, 1765.5       , 1808.33333333,
#        1737.83333333, 1732.66666667, 1726.5       , 1826.33333333,
# ...

# %%
random_optimal_ranking_distance_gurobi_mean = np.mean(random_optimal_ranking_distance_gurobi)
random_optimal_ranking_distance_gurobi_mean
# Out:
# 1757.535
